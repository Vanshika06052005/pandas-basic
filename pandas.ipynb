# %% [markdown]
# <a href="https://colab.research.google.com/github/Vanshika06052005/pandas-basic/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
country=['India','pakistan','USA','Nepal']
pd.Series(country)
# Out:
# 0       India
# 1    pakistan
# 2         USA
# 3       Nepal
# dtype: object

# %%
runs=[12,14,20,5]
pd.Series(runs)
# Out:
# 0    12
# 1    14
# 2    20
# 3     5
# dtype: int64

# %%
runs=[12,14,20,5]
player=['aman','raghu','shreya','manish']
pd.Series(runs,index=player,name='Scorers')
# Out:
# aman      12
# raghu     14
# shreya    20
# manish     5
# Name: Scorers, dtype: int64

# %%
runs=[12,14,20,5]
player=['aman','raghu','shreya','manish']
pd.Series(runs,index=player,name='Scorers').size
# Out:
# 4

# %%
import pandas as pd
df=pd.read_csv('/content/subs.csv')
series=df.squeeze()
series
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-132704977.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv('/content/subs.csv')
#       3 series=df.squeeze()
#       4 series
#
# ...

# %%
Scorers[2:4]=[100,100]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3734169824.py in <cell line: 0>()
# ----> 1 Scorers[2:4]=[100,100]
#
# NameError: name 'Scorers' is not defined

# %%
import pandas as pd

runs=[12,14,20,5]

player=['aman','raghu','shreya','manish']
run=pd.Series(runs,index=player,name='Scorers')

run
# Out:
# aman      12
# raghu     14
# shreya    20
# manish     5
# Name: Scorers, dtype: int64

# %%
#python built in function on series
print(len(run))
# Out:
# 4

# %%
print(type(run))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(dir(run))
# Out:
# ['T', '_AXIS_LEN', '_AXIS_ORDERS', '_AXIS_TO_AXIS_NUMBER', '_HANDLED_TYPES', '__abs__', '__add__', '__and__', '__annotations__', '__array__', '__array_priority__', '__array_ufunc__', '__bool__', '__class__', '__column_consortium_standard__', '__contains__', '__copy__', '__deepcopy__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__divmod__', '__doc__', '__eq__', '__finalize__', '__float__', '__floordiv__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__iand__', '__ifloordiv__', '__imod__', '__imul__', '__init__', '__init_subclass__', '__int__', '__invert__', '__ior__', '__ipow__', '__isub__', '__iter__', '__itruediv__', '__ixor__', '__le__', '__len__', '__lt__', '__matmul__', '__mod__', '__module__', '__mul__', '__ne__', '__neg__', '__new__', '__nonzero__', '__or__', '__pandas_priority__', '__pos__', '__pow__', '__radd__', '__rand__', '__rdivmod__', '__reduce__', '__reduce_ex__', '__repr__', '__r
# ...

# %%
print(max(run))
# Out:
# 20

# %%
run.plot()
# Out:
# <Axes: >

# %%
run.plot(kind='bar')
# Out:
# <Axes: >

# %%
run.plot(kind='pie')
# Out:
# <Axes: ylabel='Scorers'>
